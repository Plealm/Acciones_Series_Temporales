# %% [markdown]
# Que sucede si usted hace el ACF de un AR(p)? Qué sucede
# si usted hace el PACF de un MA(q)? Lleve a cabo simulaciones para ver
# éste hecho.

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

def simular_y_graficar(ar_params=None, ma_params=None, n_samples=1000):
    if ar_params is None:
        ar_params = [1]
    if ma_params is None:
        ma_params = [1]
    
    ar = np.r_[1, -np.array(ar_params)]
    ma = np.r_[1, np.array(ma_params)]
    
    arma_process = ArmaProcess(ar, ma)
    y = arma_process.generate_sample(n_samples)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    plot_acf(y, ax=axes[0], lags=20)
    plot_pacf(y, ax=axes[1], lags=20)
    axes[0].set_title('ACF')
    axes[1].set_title('PACF')
    plt.tight_layout()
    plt.show()

# Simular AR(2)
print("Simulación de AR(2)")
simular_y_graficar(ar_params=[0.6, -0.3])

# Simular MA(2)
print("Simulación de MA(2)")
simular_y_graficar(ma_params=[0.6, 0.3])
# Out:
# Simulación de AR(2)
# Simulación de MA(2)
